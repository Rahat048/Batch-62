# %%
import openai
import os
#import dotenv

#from dotenv import load_dotenv, find_dotenv = load_dotenv(find_dotenv{})

openai.api_key = os.getenv('OPENAI_API_KEY')
model = "gpt-3.5-turbo"

def get_completion(prompt, model="get-3.5-turbo"):
    messages = [{"role" : "user", "content" : prompt}]
    response = openai.ChatCompletion.create(model = model, messages = messages, temperature = 0)
    return response.choice[0].message["content"]

# %%
text = f""" their are so many ways to express yur feling infront of yur parents\
    like helo dad or mom\
    hi my gurdians. """

prompt = f""" summarize the text delimited by triple backticks into a single sentence. ```{text}``` """

response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[3], line 7
#       1 text = f""" their are so many ways to express yur feling infront of yur parents\
#       2     like helo dad or mom\
#       3     hi my gurdians. """
#       5 prompt = f""" summarize the text delimited by triple backticks into a single sentence. ```{text}``` """
# ----> 7 response = get_completion(prompt)
#       8 print(response)
#
# Cell In[2], line 12, in get_completion(prompt, model)
#      10 def get_completion(prompt, model="get-3.5-turbo"):
#      11     messages = [{"role" : "user", "content" : prompt}]
# ---> 12     response = openai.ChatCompletion.create(model = model, messages = messages, temperature = 0)
#      13     return response.choice[0].message["content"]
#
# ...

# %% [markdown]
# # Gemnai Api
#
# - curl \
#   -H "Content-Type: application/json" \
#   -d "{\"contents\":[{\"parts\":[{\"text\":\"Explain how AI works\"}]}]}" \
#   -X POST "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key=YOUR_API_KEY"
#
# ## Key
#
# - AIzaSyDgah1HWv0Wd_liKJbtPrlCLyRHpCqLBmU
