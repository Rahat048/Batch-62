# %%
x: dict = {'1': 'apple', '2': 'banana', '3': 'cherry'}
print(x)
# Out:
# {'1': 'apple', '2': 'banana', '3': 'cherry'}

# %%
x['3']
# Out:
# 'cherry'

# %%
for y in x.values():
    print(y)
# Out:
# apple
# banana
# cherry

# %%
x.items()
# Out:
# dict_items([('1', 'apple'), ('2', 'banana'), ('3', 'cherry')])

# %%
for i, y in x.items():
    print(f'Index:{i} Value:{y}')
# Out:
# Index:1 Value:apple
# Index:2 Value:banana
# Index:3 Value:cherry

# %%
students:dict = {'rollno#': [101, 102, 103, 104], 'name':['ali', 'ahmad', 'qureshi', 'shahid']}
print(students)
# Out:
# {'rollno#': [101, 102, 103, 104], 'name': ['ali', 'ahmad', 'qureshi', 'shahid']}
