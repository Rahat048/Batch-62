# %%
from typing import Dict, Union
my_dict: Dict[str, Union[str, float, list, int]] = {'name': 'Rahat', 'age':20, 'height':5.9, 'favrt_fruits':['banana', 'apple', 'orange']}
print(my_dict)
# Out:
# {'name': 'Rahat', 'age': 20, 'height': 5.9, 'favrt_fruits': ['banana', 'apple', 'orange']}

# %% [markdown]
# # Dictionary
#
# **Typing**
#
# - when we use typing method in dict we declare keys and items type in our dict as shown above.
#
# - first we declare key type than items type.
#
# - their should be a coma separated between key and items type.

# %%
square_numb:dict = {1: 1**2 for i in range(5)}
print(square_numb)
# Out:
# {1: 1}
