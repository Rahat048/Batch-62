# %% [markdown]
# # While Loop
#
# **Infinite loop**
#
# - Type of loop which run infinty util we don't give that a condition.

# %%
n: int = 1
while n < 10:
    print(n)
    n += 2
# Out:
# 1
# 3
# 5
# 7
# 9
