# %% [markdown]
# NumPy(Library)
#
# - Use to handle arrays.
#
# - Array is a type of list in which we can store same type of data.

# %%
numb : list = [1, 2, 3, 'Apple']
print(numb)
# Out:
# [1, 2, 3, 'Apple']

# %%
import numpy as np
arr = np.array(numb)
print(arr)
# Out:
# ['1' '2' '3' 'Apple']
