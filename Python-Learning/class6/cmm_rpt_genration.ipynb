# %%
print('Line:RT-FC-LNE\nPerpendicular\t0.753\t0.300,FA(FR-PREP-LNE)\t\t+-->\t0.453')
# Out:
# Line:RT-FC-LNE
# Perpendicular	0.753	0.300,FA(FR-PREP-LNE)		+-->	0.453

# %%
x:str = ('Line:CTN-LNE')
y:str = ('Perpendicular')
z:str = ('(TOP-FACE-A)')
user_input = float(input('Please enter data'))
PERPENDICULAR:float = 0.030
if user_input <= 0.005:
 print(f'{x}\n{y}\t{user_input}\t{PERPENDICULAR},FA{z}\t\t\t*---')
elif user_input >= 0.006 and user_input <= 0.015:
 print(f'{x}\n{y}\t{user_input}\t{PERPENDICULAR},FA{z}\t\t\t+*--')
elif user_input >= 0.016 and user_input <= 0.025:
 print(f'{x}\n{y}\t{user_input}\t{PERPENDICULAR},FA{z}\t\t\t+-*-')
elif user_input >= 0.026 and user_input <= 0.030:
 print(f'{x}\n{y}\t{user_input}\t{PERPENDICULAR},FA{z}\t\t\t+--*')
else:
 print(f'{x}\n{y}\t{user_input}\t{PERPENDICULAR},FA{z}\t\t\t+-->\t\t{(user_input - 0.030):.3f}')
# Out:
# Line:CTN-LNE
# Perpendicular	0.037	0.03,FA(TOP-FACE-A)			+-->		0.007
