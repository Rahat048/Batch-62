# %%
name_input = input('Please enter your name')
print(f'Hi {name_input.title()} well come to number game.')
# Out:
# Hi Rahat well come to number game.

# %%
num1 = int(input('Please enter your 1st no.'))
print(f'This is your 1st no: {num1}')
# Out:
# This is your 1st no: 1

# %%
num2 = int(input('Please enter your 2nd no.'))
print(f'This is your 2nd no: {num2}')
# Out:
# This is your 2nd no: 2

# %%
num3 = int(input('Please enter your 3rd no.'))
print(f'This is your 3rd no: {num3}')
# Out:
# This is your 3rd no: 3
