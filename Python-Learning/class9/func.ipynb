# %%
def greet(name):
    print("Hello, " + name)
    return "Greetings sent!"

result = greet("John")
print(result)  # Output: Greetings sent!
# Out:
# Hello, John
# Greetings sent!

# %%
def tea_making(milk:float, tea:float, sugar:float) -> float:

    if milk == tea and milk == sugar:
        print('\nThe tea is excellent.')
    elif milk/tea or tea/milk == 0.5:
        print("\nThe tea is good.")
    elif milk/sugar or sugar/milk == 0.5:
        print("\nThe tea is good.")
    else:
        print("\nThe tea is bad.")

tea_making( milk = input("\nEnter cup of milk:- "), tea = input("\nEnter spoon of tea:- "), sugar = input("\nEnter spoon of sugar:- "))
# Out:
# The tea is excellent.
