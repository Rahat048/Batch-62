# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahat048/Batch-62/blob/main/langchain_hello_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install langchain_google_genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
GEMINI_KEY=userdata.get('GOOGLE_API_KEY')

# %%
import os
os.environ["GOOGLE_API_KEY"] = GEMINI_KEY

# %%
llm = ChatGoogleGenerativeAI(
    api_key=GEMINI_KEY,
    model="gemini-2.0-flash-exp",
    temperature=0.7,
    max_tokens= 100
)

# %%
from langchain.prompts import PromptTemplate

# %%
prompt1 = PromptTemplate(
    input_variables=["question"],
    template="You are a helpful assistant. Answer the following question:\n\n{question}"
)

# %%
chain1 = prompt1 | llm

# %%
question = input("Ask me any thinq? ")
response = chain1.invoke({"question": question})
# Out:
# Ask me any thinq? write a short poem?

# %%
print("Answer:", response.content)
# Out:
# Answer: Okay, here's a short poem for you:
#
# The sun dips low, a fiery kiss,
# On clouds that blush a soft amethyst.
# The world grows still, a gentle sigh,
# As day surrenders to the sky.
